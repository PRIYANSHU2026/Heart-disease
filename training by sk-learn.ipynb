# %% [markdown]
# # Training

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
a=pd.read_csv("/Users/shikarichacha/Desktop/PROJECT /1.csv")
a
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
a.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
a.shape
# Out:
# (303, 14)

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
a.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
# Histogram
a.hist(figsize=(12, 10))
plt.suptitle('Histograms of Features', y=1.02)
plt.show()

# %%
sns.boxplot(x=a["age"])
sns.boxplot(x=a["sex"])
# Out:
# <Axes: xlabel='sex'>

# %%
sns.scatterplot(data=a,x="trestbps",y="thalach")
# Out:
# <Axes: xlabel='trestbps', ylabel='thalach'>

# %%
# Pairplot
sns.pairplot(a, diag_kind='kde')
plt.suptitle('Pairplot of Features', y=1.02)
plt.show()
# Out:
# /Users/shikarichacha/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
x=a.iloc[:,:-1]
y=a.iloc[:,:-1]
x,y
# Out:
# (     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
#  0     63    1   3       145   233    1        0      150      0      2.3
#  1     37    1   2       130   250    0        1      187      0      3.5
#  2     41    0   1       130   204    0        0      172      0      1.4
#  3     56    1   1       120   236    0        1      178      0      0.8
#  4     57    0   0       120   354    0        1      163      1      0.6
#  ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
#  298   57    0   0       140   241    0        1      123      1      0.2
#  299   45    1   3       110   264    0        1      132      0      1.2
#  300   68    1   0       144   193    1        1      141      0      3.4
#  301   57    1   0       130   131    0        1      115      1      1.2
#  302   57    0   1       130   236    0        0      174      0      0.0
#
#       slope  ca  thal
#  0        0   0     1
#  1        0   0     2
# ...

# %%
# Correlation graph
corr = a.corr()
plt.figure(figsize=(12, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
# Pie chart
plt.figure(figsize=(8, 8))
a['sex'].value_counts().plot.pie(autopct='%1.1f%%', colors=['skyblue', 'salmon'])
plt.title('Sex Distribution')
plt.ylabel('')
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
x1,x2,y1,y2=train_test_split(x,y,test_size=0.2,random_state=50)
x1.head()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 168   63    1   0       130   254    0        0      147      0      1.4
# 66    51    1   2       100   222    0        1      143      1      1.2
# 148   44    1   2       120   226    0        1      169      0      0.0
# 290   61    1   0       148   203    0        1      161      0      0.0
# 222   65    1   3       138   282    1        0      174      0      1.4
#
#      slope  ca  thal
# 168      1   1     3
# 66       1   0     2
# 148      2   0     2
# 290      2   1     3
# 222      1   1     2

# %%
#trainig model
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()
model.fit(x1,y1)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([[ 1.00000000e+00,  1.60762455e-16, -2.09059672e-16,
#         -1.39640870e-16,  1.02943006e-16, -1.24660517e-16,
#         -1.62629656e-16,  7.80236409e-17, -4.02790902e-16,
#         -9.32835975e-18, -1.09476520e-16, -6.67824616e-17,
#          2.85700891e-16],
#        [ 5.75615332e-16,  1.00000000e+00,  2.42412236e-15,
#         -5.82576308e-17, -3.91310675e-17,  5.89308207e-16,
#         -5.18612762e-16,  3.20248598e-17, -5.78144833e-16,
#         -7.93922958e-17,  7.68988670e-17, -6.42268496e-17,
#          3.84994680e-16],
#        [ 1.91386173e-16, -7.51135265e-16,  1.00000000e+00,
#         -9.24813258e-17, -2.59860722e-16, -1.65874144e-16,
#          5.70726111e-16,  1.66506463e-16, -3.88602152e-16,
#         -1.47182014e-16,  5.28576961e-17,  1.72693534e-16,
#         -1.41205058e-16],
#        [ 2.38229051e-16, -8.88178420e-16, -2.75661523e-15,
#          1.00000000e+00, -3.33559494e-17,  3.28849439e-16,
#         -9.50906172e-16, -3.13333774e-16,  1.60336945e-15,
# ...

# %%
model.intercept_
# Out:
# array([-4.26325641e-14, -2.64233080e-14,  4.18554080e-14,  2.55795385e-13,
#        -8.52651283e-14,  1.02695630e-14, -3.44169138e-15, -5.68434189e-14,
#        -1.23234756e-14, -6.57252031e-14,  2.10942375e-14, -1.75415238e-14,
#        -1.42108547e-14])

# %%
yp=model.predict(x2)
yp
# Out:
# array([[ 6.40000000e+01, -1.06177565e-16,  2.00000000e+00,
#          1.40000000e+02,  3.13000000e+02,  2.68988815e-15,
#          1.00000000e+00,  1.33000000e+02, -4.02992644e-16,
#          2.00000000e-01,  2.00000000e+00,  1.81419119e-15,
#          3.00000000e+00],
#        [ 4.10000000e+01,  1.00000000e+00,  1.00000000e+00,
#          1.35000000e+02,  2.03000000e+02, -1.41777172e-15,
#          1.00000000e+00,  1.32000000e+02, -2.11742524e-15,
#         -2.08418279e-14,  1.00000000e+00, -1.13758851e-14,
#          1.00000000e+00],
#        [ 4.60000000e+01,  1.00000000e+00, -2.35375694e-15,
#          1.20000000e+02,  2.49000000e+02,  2.41811540e-15,
#          5.79148292e-16,  1.44000000e+02, -1.81301617e-15,
#          8.00000000e-01,  2.00000000e+00, -4.44686822e-15,
#          3.00000000e+00],
#        [ 6.50000000e+01, -1.87244484e-15,  2.00000000e+00,
#          1.60000000e+02,  3.60000000e+02,  7.56482489e-16,
#          3.89189121e-16,  1.51000000e+02,  1.50536189e-16,
# ...

# %%
y2
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 112   64    0   2       140   313    0        1      133      0      0.2
# 63    41    1   1       135   203    0        1      132      0      0.0
# 270   46    1   0       120   249    0        0      144      0      0.8
# 39    65    0   2       160   360    0        0      151      0      0.8
# 277   57    1   1       124   261    0        1      141      0      0.3
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 283   40    1   0       152   223    0        1      181      0      0.0
# 15    50    0   2       120   219    0        1      158      0      1.6
# 175   40    1   0       110   167    0        0      114      1      2.0
# 124   39    0   2        94   199    0        1      179      0      0.0
# 81    45    1   1       128   308    0        0      170      0      0.0
#
#      slope  ca  thal
# 112      2   0     3
# 63       1   0     1
# 270      2   0     3
# ...

# %%
model.score(x2,y2)*100
# Out:
# 100.0

# %%
model.score(x1,y1)
# Out:
# 1.0

# %%
# Validation graph
plt.figure(figsize=(10, 6))
plt.scatter(y2, yp, color='blue')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Validation Graph')
plt.show()

# %% [markdown]
# # Testing

# %%
# Example prediction
example_data = [[63, 1, 3, 145, 233, 1, 0, 150, 0, 2.3, 0, 0, 1]]
example_prediction = model.predict(example_data)

if 0 in example_prediction:
    print("Example Prediction: Normal Heart Condition (No Heart Attack)")
else:
    print("Example Prediction: Severe Heart Condition (Likelihood of Heart Attack)")
# Out:
# Example Prediction: Severe Heart Condition (Likelihood of Heart Attack)
# /Users/shikarichacha/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # Basic UI

# %%
import matplotlib.pyplot as plt
import numpy as np
import pickle

# Function to predict heart attack risk and message
def predict_heart_attack(age, sex, cp, trestbps, chol, fbs, restecg, thalach, exang, oldpeak, slope, ca, thal):
    features = [[age, sex, cp, trestbps, chol, fbs, restecg, thalach, exang, oldpeak, slope, ca, thal]]
    prediction = model.predict(features)
    if np.any(prediction > 5):



        return prediction, "You have a high risk of heart attack. Please consult a doctor immediately."
    else:
        return prediction, "Your risk of heart attack is low. No immediate concern."

# Get user inputs
age = float(input("Enter age: "))
sex = float(input("Enter sex (0 = female, 1 = male): "))
cp = float(input("Enter cp (0 = typical angina, 1 = atypical angina, 2 = non-anginal pain, 3 = asymptomatic): "))
trestbps = float(input("Enter trestbps (resting blood pressure): "))
chol = float(input("Enter chol (serum cholesterol): "))
fbs = float(input("Enter fbs (fasting blood sugar > 120 mg/dl, 1 = true; 0 = false): "))
restecg = float(input("Enter restecg (resting electrocardiographic results): "))
thalach = float(input("Enter thalach (maximum heart rate achieved): "))
exang = float(input("Enter exang (exercise induced angina, 1 = yes; 0 = no): "))
oldpeak = float(input("Enter oldpeak (ST depression induced by exercise relative to rest): "))
slope = float(input("Enter slope (the slope of the peak exercise ST segment): "))
ca = float(input("Enter ca (number of major vessels colored by fluoroscopy): "))
thal = float(input("Enter thal (3 = normal; 6 = fixed defect; 7 = reversible defect): "))

# Specify the path to the model file
model_path = "/Users/shikarichacha/Desktop/PROJECT /heart_attack_model.pkl"

# Load the model
with open(model_path, 'rb') as file:
    model = pickle.load(file)

# Predict
prediction, message = predict_heart_attack(age, sex, cp, trestbps, chol, fbs, restecg, thalach, exang, oldpeak, slope, ca, thal)

# Create plots
fig, axs = plt.subplots(3)
fig.suptitle('Your Health Stats')
axs[0].hist([age], bins=10, color='blue', alpha=0.7)
axs[0].set_title('Age Distribution')
axs[0].set_xlabel('Age')
axs[0].set_ylabel('Frequency')

axs[1].hist([chol], bins=10, color='green', alpha=0.7)
axs[1].set_title('Cholesterol Distribution')
axs[1].set_xlabel('Cholesterol')
axs[1].set_ylabel('Frequency')

axs[2].hist([thalach], bins=10, color='red', alpha=0.7)
axs[2].set_title('Heart Rate Distribution')
axs[2].set_xlabel('Heart Rate')
axs[2].set_ylabel('Frequency')

# Show plots
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# Display prediction and message
print("Prediction:", prediction)
print("Message:", message)
# Out:
# Enter age: 21
# Enter sex (0 = female, 1 = male): 1
# Enter cp (0 = typical angina, 1 = atypical angina, 2 = non-anginal pain, 3 = asymptomatic): 1
# Enter trestbps (resting blood pressure): 120
# Enter chol (serum cholesterol): 23
# Enter fbs (fasting blood sugar > 120 mg/dl, 1 = true; 0 = false): 1
# Enter restecg (resting electrocardiographic results): 1
# Enter thalach (maximum heart rate achieved): 1344
# Enter exang (exercise induced angina, 1 = yes; 0 = no): 1
# Enter oldpeak (ST depression induced by exercise relative to rest): 2.5
# Enter slope (the slope of the peak exercise ST segment): 1
# Enter ca (number of major vessels colored by fluoroscopy): 0
# Enter thal (3 = normal; 6 = fixed defect; 7 = reversible defect): 3
# /Users/shikarichacha/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# ...
